# %%
import mne
import nilearn
import nibabel
import brainstat
import brainspace
import pyvista
import pyvistaqt
import skbio
from Bio import __version__ as biopython_version
import statsmodels
import biom
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import sklearn

print("mne:", mne.__version__)
print("nilearn:", nilearn.__version__)
print("nibabel:", nibabel.__version__)
print("brainstat:", brainstat.__version__)
print("brainspace:", brainspace.__version__)
print("pyvista:", pyvista.__version__)
print("pyvistaqt:", pyvistaqt.__version__)
print("scikit-bio:", skbio.__version__)
print("biopython:", biopython_version)
print("statsmodels:", statsmodels.__version__)
print("biom-format:", biom.__version__)
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("matplotlib:", matplotlib.__version__)
print("seaborn:", sns.__version__)
print("scikit-learn:", sklearn.__version__)
# Out:
# mne: 1.11.0
# nilearn: 0.13.0
# nibabel: 5.3.2
# brainstat: 0.5.2
# brainspace: 0.1.22
# pyvista: 0.46.5
# pyvistaqt: 0.11.3
# scikit-bio: 0.7.1.post1
# biopython: 1.86
# statsmodels: 0.14.6
# biom-format: 2.1.17
# pandas: 2.3.3
# numpy: 2.2.6
# matplotlib: 3.10.8
# seaborn: 0.13.2
# scikit-learn: 1.7.2

# %%
s = '''mne: 1.11.0
nilearn: 0.13.0
nibabel: 5.3.2
brainstat: 0.5.2
brainspace: 0.1.22
pyvista: 0.46.5
pyvistaqt: 0.11.3
scikit-bio: 0.7.1.post1
biopython: 1.86
statsmodels: 0.14.6
biom-format: 2.1.17
pandas: 2.3.3
numpy: 2.2.6
matplotlib: 3.10.8
seaborn: 0.13.2
scikit-learn: 1.7.2'''

s = s.replace(':',' ==')
print(s)
# Out:
# mne == 1.11.0
# nilearn == 0.13.0
# nibabel == 5.3.2
# brainstat == 0.5.2
# brainspace == 0.1.22
# pyvista == 0.46.5
# pyvistaqt == 0.11.3
# scikit-bio == 0.7.1.post1
# biopython == 1.86
# statsmodels == 0.14.6
# biom-format == 2.1.17
# pandas == 2.3.3
# numpy == 2.2.6
# matplotlib == 3.10.8
# seaborn == 0.13.2
# scikit-learn == 1.7.2
